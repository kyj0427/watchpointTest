# %%
from urllib import request as req
from bs4 import BeautifulSoup
import csv
import requests
import pandas as pd


ranks = ['S','A']
all_players = []  # 여기에 선수 이름들 저장

for rank in ranks:
    url = f"https://liquipedia.net/overwatch/{rank}-Tier_Tournaments"
    res = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    soup = BeautifulSoup(res.text, 'html.parser')

    competition = []

    target_div = soup.select_one('div.gridTable.tournamentCard.Tierless.NoGameIcon')

    if target_div:
        a_tags = target_div.select('div.gridCell.Tournament.Header > a')
        for a in a_tags:
            href = a.get('href')
            if href:
                full_url = f"https://liquipedia.net{href}"
                competition.append(full_url)
    else:
        print("타겟 div를 찾을 수 없습니다.")

    for comp_url in competition:
        res = requests.get(comp_url)
        soup = BeautifulSoup(res.text, 'html.parser')

        players = soup.select(
            '#mw-content-text div.teamcard.toggle-area.toggle-area-1 div.teamcard-inner table[data-toggle-area-content="1"] tbody tr td > a'
        )

        if players:
            for p in players:
                name = p.text.strip()
                all_players.append(name)  # 전역 리스트에 추가
        else:
            print("❌ 선수 또는 팀 정보를 찾을 수 없습니다.")

# %%
all_players = list(set(all_players))
# 모든 선수 이름 출력
print(all_players)
# Out:
# ['tunder', 'speed75', 'Hesty', 'Zeb', 'pela', 'mazz', 'cookie084', 'Remaker', 'Aki', 'D4RT', 'FREGRE', 'pokotaros', 'Esteban', 'Eileen', 'hamster', 'Faith', 'revzi', 'Prophet', 'Kurumi', 'Taejong', 'WoochaN', 'D0NGHAK', 'UYOU', 'cuFFa', 'Seicoe', 'DML', 'Mealgaru', 'Youbi', 'ProYung', 'Tamper', 'StillKIWI', 'scuffed', 'TwolzZ', 'KSG', 'Khenail', 'yoham', 'R3K', 'crispy', 'Dip', 'Lengsa', 'Estreichh', 'gogo', 'Exrai', 'Juno', 'Simple', 'Danny', 'MAKA', 'Hry', 'Ado', 'Ewan', 'Xzahyo', 'Kellex', 'Architect', 'Insane', 'SKAI', 'Jasm1ne', 'Bilideng', 'slowdive', 'nuka', 'Genius91', 'Attack', 'decade', 'Twe12e', 'Viper', 'meruna', 'AOY', 'knife', 'GaaRa', 'JBJ', 'Ryujehong', 'Sauna', 'Despair', 'pOv', 'K4ne', 'Ken', 'Dumbbell', 'Love', 'Fone', 'Proud', 'FARMER', 'fya', 'AMANE', 'Aniyun', 'Langley', 'Leonopteryx', 'MER1T', 'Astro', 'KIVIS', 'lumi', 'Proxy', 'dra', 'seeker', 'Lukemino', 'winter', 'elva', 's9mm', 'WGYM', 'JayCo', 'PaLee', 'ZEST', 'Maybe', 'ARLLY', 'Cjay', 'Junbin', 'D0D0', 'KL1', '1zU', 'Casanova', 'Kyrei', 'Leedy', 'Mimoza', 'ChoiSehwan', 'ZzetaA', 'Renko', 'EuclidEUC', 'Diya', 'FDGod', 'zeruhh', 'Daisy', 'cjay', 'Chu', 'GFONAFASK', 'UltraViolet', 'Akie', 'NuoRan', 'ChiYo', 'Kio', 'HYE', 'Haku', 'Rakattack', 'Flora', 'Chase', 'Qlm', 'eisgnom', 'Tred', 'Qloud', 'GAP', 'AZent', 'Drunk', 'Vision', 'BILIDENG', 'Nico', 'Becky', 'Damo', 'Lumi', 'SoloZen', 'Sungeun', 'guxue', 'Hop3r', 'feiyang', 'HEISER', 'JinMu', 'Sour4', 'iMOH97', 'SeungAn', 'Edison', 'Gaisen', 'Majin', 'Aester', 'Proxiezs', 'Univ2r', 'WhoRU', 'Landon', 'Misin', 'Mew', 'Rrmy', 'par', 'xzodyal', 'Kellan', 'HINIS4Ku', 'Mercury', 'Tom4to', 'Rohan', 'Wh4le', 'F1nally', 'zox', 'Bliss', 'Prota', 'LtNest', 'Twilight', 'Arise', 'Vosa1q', 'PEPPI', 'Axure', 'Whoru', 'One', 'November', 'MAX', 'Rokit', 'Overshake', 'CheckMate', 'Remedy', 'JONGWOO', 'Kilo', 'LBBD7', 'Epic', 'NHZ', 'Seqtar', 'HaoYoQian', 'Xeriongdh', 'Dank', 'HEESUNG', 'Yunko', 'Sley', 'SWOO', 'CHATCHAI', 'Scarlett', 'Hypnotic', 'RAYMOMO', 'sugarfree', 'SUZUME', 'Ydot', 'Grapes', 'KiWii', 'Undersea', 'Farway1987', 'Vestola', 'Proper', 'Catlight', 'xten', 'Pineapple', 'China', 'v1ctory', 'Ecc', 'ARCHE', 'Suraimu', 'Wolf', 'pdk', 'Mashiro', 'LUX', 'epic', 'selfish', 'Raikker', 'HeeSang', 'Strebor', 'Kani', 'NenWhy', 'CrazyCat', 'Ade', 'Takoyaki', 'WilmaFistFit', 'Chopper', 'Ezhan', 'Dororo', 'D0nghun', 'Lavender', 'Hope', 'GACHAPIN', 'pressure', 'Leave', 'Zydra', 'Action', 'Solo', 'Poke', 'yumilalan', 'Mihawk', 'BERNAR', 'sHockWave', 'FiNN', 'MCD', 'Ace', 'Maltma', 'Hitori', 'Exia', 'SeonJun', 'Punk', 'Kutoto', 'Admiral', 'BaLLisTa', 'Tomosa', 'Mag', 'Galaa', 'tengyuan', 'M1NUT2', 'Stalk3r', 'Hanbin', 'eYeKu', 'SORI', 'kiru01', 'baz', 'LiGe', 'Yoshinori2k', 'squid', 'Neivis', 'Kyo', 'DOX', 'xomba', 'OLAM', 'Graveyard', 'Beeple', 'Skytorr', 'CCJPITY', 'Sakume', 'FiXa', 'BreadTurtle', 'Argon', 'TR33', 'Apr1ta', 'skewed', 'Mazz', 'Keiou', 'Kairen', 'KSAA', 'JaeWoo', 'shkyp', 'Jaelun', 'Yott1y', 'Romani', 'Sp1nel', 'Vega', 'Kotaro', 'Prologue', 'Qutyan', 'Rajeem', 'rzr', 'Meng', 'Willys07', 'Momoga', 'Painkiller', 'Pelican', 'Kiibo', 'MuZe', 'Kame', 'Hadi', 'Arc', 'NewJ', 'OPENER', 'Soll', 'A1IEN', 'Hysteria', 'Schwi', 'Winter', 'SP1NT', 'shy', 'Noricutea', 'TOPDRAGON', 'Kalios', 'Vindaim', 'FunnyAstro', 'Hamumaru', 'intark', 'Quartz', 'Zorrow', 'Soulsay', 'WMaimone', 'Farway2025', 'Unkn0w', 'Osato', 'Frogger', 'Maksal', 'CQB', 'CINNAMON', 'Mmonk', 'sgy', 'Natsuki', 'Rupal', 'RhynO', 'Fari', 'Gilly', 'LadyLu', 'M00N', 'Shu', 'PAK', 'cinnabar', 'ZIYAD', 'CLEAR', 'RLG5656', 'redex', 'Roxy', 'peace', 'JUTSU', 'irony', 'XLIM', 'Joo', 'JY2006', 'Jaya', 'DMS', 'Fielder', 'Achieve', 'Angey', 'Asuna', 'Xii', 'SOMEONE', 'zzz', 'AlphaYi', 'nvm', 'HVS', 'M0CHA', 'JINSUNG', 'Lethal', 'TOMITAKEexe', 'Ryan', 'Jae', 'Crimsyn', 'qki', 'Hofac', 'kevster', 'CH0R0NG', 'FrothyFilly7', 'Pride', 'Mememachine', 'Kim', 'Netra', 'Alphari', 'Mayweather', 'ike', 'Lep', 'Abbs', 'elia', 'Jeremy', 'icesoul', 'Qiezi', 'Meruna', 'Secret', ' ...

# %%
fields = [
    "Player", "Romanized Name", "Nationality", "Born", "Status",
    "Role", "Team", "Signature Heroes", "Game Appearances", "Approx. Total Winnings"
]

def get_player_info(player_name):
    url = f"https://liquipedia.net/overwatch/{player_name}"
    res = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    soup = BeautifulSoup(res.text, 'html.parser')

    info = {field: "" for field in fields}
    info["Player"] = player_name

    # Romanized Name 보완
    name_divs = soup.select("div.infobox-center .infobox-cell-2")
    if len(name_divs) >= 2:
        name_kr = name_divs[0].get_text(strip=True)
        name_en = name_divs[1].get_text(strip=True)
        if not all(ord(c) < 128 for c in name_kr):
            info["Romanized Name"] = name_en

    # 필드 매핑
    field_map = {
        "Romanized Name": "Romanized Name",
        "Nationality": "Nationality",
        "Born": "Born",
        "Status": "Status",
        "Role": "Role", "Roles": "Role",
        "Team": "Team", "Teams": "Team",
        "Signature Heroes": "Signature Heroes",
        "Game Appearances": "Game Appearances",
        "Approx. Total Winnings": "Approx. Total Winnings"
    }

    labels = soup.select("div.infobox-cell-2.infobox-description")
    for label in labels:
        key = label.get_text(strip=True).rstrip(":")
        value_div = label.find_next_sibling("div")
        if not value_div:
            continue

        if key == "Signature Heroes":
            value = ", ".join(tag['title'] for tag in value_div.select('a[title]'))
        else:
            value = value_div.get_text(" ", strip=True)

        if key in field_map:
            target_field = field_map[key]
            if target_field == "Romanized Name" and info[target_field]:
                continue
            info[target_field] = value

    return info


for player in all_players:
    try:
        data = get_player_info(player)
        print(data)
    except Exception as e:
        print(f"Error fetching data for {player}: {e}")
# Out:
# {'Player': 'tunder', 'Romanized Name': '', 'Nationality': 'Brazil', 'Born': 'April 26, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'ZoKorp Esports', 'Signature Heroes': 'Sojourn, Tracer, Cassidy', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$140'}
# {'Player': 'speed75', 'Romanized Name': '', 'Nationality': 'Indonesia Saudi Arabia', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Cold Metal', 'Signature Heroes': 'Tracer, Ashe, Pharah', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$3,729'}
# {'Player': 'Hesty', 'Romanized Name': 'Yoshikazu Honda', 'Nationality': 'Japan', 'Born': 'September 17, 1999 (age\xa025)', 'Status': 'Active', 'Role': 'Support', 'Team': 'REVATI', 'Signature Heroes': 'Lúcio, Baptiste, Brigitte', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,421'}
# {'Player': 'Zeb', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'January 27, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Sakura Esports', 'Signature Heroes': 'Orisa, Sigma, Ramattra', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$6,162'}
# {'Player': 'pela', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'January 21, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Dreamland', 'Signature Heroes': 'Wrecking Ball, Winston, Mauga', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$3,840'}
# {'Player': 'mazz', 'Romanized Name': '', 'Nationality': 'Japan', 'Born': 'January 14, 2001 (age\xa024)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Aplomb Tiger', 'Signature Heroes': 'Ana, Zenyatta, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,447'}
# {'Player': 'cookie084', 'Romanized Name': '', 'Nationality': 'Germany', 'Born': '', 'Status': 'Active', 'Role': 'DPS Coach', 'Team': 'Team Peps', 'Signature Heroes': 'Sojourn, Widowmaker', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$11,998'}
# {'Player': 'Remaker', 'Romanized Name': 'Yi Jiajun', 'Nationality': 'China', 'Born': 'October 29, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'ZONES', 'Signature Heroes': 'Freja, Sojourn, Cassidy', 'Game Appearances': '', 'Approx. Total Winnings': '$837'}
# {'Player': 'Aki', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'D4RT', 'Romanized Name': 'Go Min-hyuk', 'Nationality': 'South Korea', 'Born': 'November 15, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Poker Face', 'Signature Heroes': 'Genji, Tracer, Venture', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$4,082'}
# {'Player': 'FREGRE', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'pokotaros', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Esteban', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Eileen', 'Romanized Name': 'Ou Yiliang', 'Nationality': 'China', 'Born': 'September 26, 2000 (age\xa024)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Milk Tea', 'Signature Heroes': 'Genji, Sombra, Tracer', 'Game Appearances': '', 'Approx. Total Winnings': '$36,546'}
# {'Player': 'hamster', 'Romanized Name': '', 'Nationality': 'Australia', 'Born': '', 'Status': 'Active', 'Role': 'Support', 'Team': 'FURY', 'Signature Heroes': 'Moira, Mercy, Lifeweaver', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$755'}
# {'Player': 'Faith', 'Romanized Name': 'Kim Hong-gyu', 'Nationality': 'South Korea', 'Born': 'November 16, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Support Coach', 'Team': '', 'Signature Heroes': 'Lúcio, Mercy, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$14,985'}
# {'Player': 'revzi', 'Romanized Name': '', 'Nationality': 'New Zealand Philippines', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': '', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,224'}
# {'Player': 'Prophet', 'Romanized Name': 'Kim Hyun-been', 'Nationality': 'South Korea', 'Born': 'September 27, 2005 (age\xa019)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Widowmaker, Ashe, Cassidy', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$16,286'}
# {'Player': 'Kurumi', 'Romanized Name': 'So Chun-kit', 'Nationality': 'Hong Kong', 'Born': 'November  2, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Widowmaker, Ashe, Sojourn', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$2,430'}
# {'Player': 'Taejong', 'Romanized Name': 'Yoo Tae-jong', 'Nationality': 'South Korea', 'Born': 'August  1, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'ROC Esports', 'Signature Heroes': 'Tracer, Widowmaker, Genji', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$7,685'}
# {'Player': 'WoochaN', 'Romanized Name': 'Lee Woo-chan', 'Nationality': 'South Korea', 'Born': 'November 26, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Support DPS', 'Team': '', 'Signature Heroes': 'Genji, Hanzo, Ana', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$13,534'}
# {'Player': 'D0NGHAK', 'Romanized Name': 'Kim Min-sung', 'Nationality': 'South Korea', 'Born': 'December  3, 2005 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'T1', 'Signature Heroes': 'Wrecking Ball, Winston, Doomfist', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$85,000'}
# {'Player': 'UYOU', 'Romanized Name': 'Um Ho-yong', 'Nationality': 'South Korea', 'Born': 'September  8, 2005 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Please Not Hero Ban', 'Signature Heroes': '', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$2,257'}
# {'Player': 'cuFFa', 'Romanized Name': '', 'Nationality': 'Australia', 'Born': 'August 19, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Geekay Esports', 'Signature Heroes': 'Winston, Wrecking Ball, Junker Queen', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$51,167'}
# {'Player': 'Seicoe', 'Romanized Name': '', 'Nationality': 'Austria', 'Born': 'November 19', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Twisted Minds', 'Signature Heroes': 'Echo, Mei, Venture', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$79,579'}
# {'Player': 'DML', 'Romanized Name': '', 'Nationality': 'Australia', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': 'FURY', 'Signature Heroes': 'Sojourn, Cassidy, Tracer', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,081'}
# {'Player': 'Mealgaru', 'Romanized Name': 'Lee Jeong-hwan', 'Nationality': 'South Korea', 'Born': 'February 25, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'All Gamers Global', 'Signature Heroes': 'Wrecking Ball, Winston, Hazard', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$8,211'}
# {'Player': 'Youbi', 'Romanized Name': 'Ahmad Alyoubi', 'Nationality': 'Saudi Arabia', 'Born': 'May  5, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Twisted Minds', 'Signature Heroes': 'Symmetra, Mei, Tracer', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$111,785'}
# {'Player': 'ProYung', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Tamper', 'Romanized Name': 'Ma Ji-min', 'Nationality': 'South Korea', 'Born': 'March 15, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Kiriko, Ana, Genji', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$3,919'}
# {'Player': 'StillKIWI', 'Romanized Name': '', 'Nationality': 'El Salvador', 'Born': 'August  6, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'ZoKorp Esports', 'Signature Heroes': 'Lúcio, Baptiste, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$3,212'}
# {'Player': 'scuffed', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'June 25, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Extinction DhillKucks', 'Signature Heroes': 'Kiriko, Baptiste, Juno', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$6,997'}
# {'Player': 'TwolzZ', 'Romanized Name': '', 'Nationality': 'Netherlands', 'Born': 'December 23, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Tank Flex', 'Team': 'Extinction', 'Signature Heroes': 'D.Va, Sigma, Zarya', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$10,878'}
# {'Player': 'KSG', 'Romanized Name': 'Inoue Tomoharu', 'Nationality': 'Japan', 'Born': '', 'Status': 'Active', 'Role': 'Tank', 'Team': 'VARREL', 'Signature Heroes': 'Winston, Doomfist, Orisa', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$10,074'}
# {'Player': 'Khenail', 'Romanized Name': '', 'Nationality': 'Spain', 'Born': 'August 20, 2005 (age\xa019)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Gen.G Esports', 'Signature Heroes': 'Baptiste, Zenyatta, Ana', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$31,068'}
# {'Player': 'yoham', 'Romanized Name': '', 'Nationality': 'Denmark', 'Born': 'July 28, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'Support', 'Team': '1DIPVS100GORILLAS', 'Signature Heroes': 'Baptiste, Kiriko, Ana', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$7,580'}
# {'Player': 'R3K', 'Romanized Name': 'Lee Yu-shek', 'Nationality': 'Hong Kong', 'Born': 'August  1, 2005 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Milk Tea', 'Signature Heroes': 'Doomfist, Junker Queen, Sigma', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$9,616'}
# {'Player': 'crispy', 'Romanized Name': '', 'Nationality': 'United Kingdom', 'Born': 'April 25, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Lúcio, Mercy, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$14,281'}
# {'Player': 'Dip', 'Romanized Name': '', 'Nationality': 'France', 'Born': 'August 28, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'DPS', 'Team': '1DIPVS100GORILLAS Frost Tails eSport', 'Signature Heroes': 'Tracer, Genji, Echo', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$5,029'}
# {'Player': 'Lengsa', 'Romanized Name': 'Chen Jingyi', 'Nationality': 'China', 'Born': 'July 30, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': 'ROC Esports', 'Signature Heroes': 'Brigitte, Lúcio, Baptiste', 'Game Appearances': '', 'Approx. Total Winnings': '$121,391'}
# {'Player': 'Estreichh', 'Romanized Name': '', 'Nationality': 'Australia Germany', 'Born': 'November 18, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Tank Coach', 'Team': 'FURY', 'Signature Heroes': 'D.Va, Sigma, Wrecking Ball', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,154'}
# {'Player': 'gogo', 'Romanized Name': '', 'Nationality': 'France', 'Born': 'September  6, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Frost Tails eSport', 'Signature Heroes': 'Lúcio, Brigitte, Baptiste', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$5,246'}
# {'Player': 'Exrai', 'Romanized Name': '', 'Nationality': 'Australia Germany', 'Born': 'June 25, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'Support', 'Team': 'FURY', 'Signature Heroes': 'Ana, Baptiste, Kiriko', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,627'}
# {'Player': 'Juno', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': 'Support', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Simple', 'Romanized Name': 'Kim Ji-sung', 'Nationality': 'South Korea', 'Born': 'December  9, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Twisted Minds', 'Signature Heroes': 'Ana, Zenyatta, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$21,509'}
# {'Player': 'Danny', 'Romanized Name': 'Ho Chun-Wei', 'Nationality': 'Taiwan', 'Born': 'October 24, 1993 (age\xa031)', 'Status': 'Inactive', 'Role': 'Caster', 'Team': '', 'Signature Heroes': '', 'Game Appearances': 'Overwatch', 'Approx. Total Winnings': '$4,506'}
# {'Player': 'MAKA', 'Romanized Name': 'Oh Eun-seok', 'Nationality': 'South Korea', 'Born': 'August 30, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'Support', 'Team': 'All Gamers Global', 'Signature Heroes': 'Zenyatta, Ana, Baptiste', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$9,164'}
# {'Player': 'Hry', 'Romanized Name': '', 'Nationality': 'Japan', 'Born': 'July 31, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Inferno', 'Signature Heroes': 'Widowmaker, Cassidy, Ashe', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,367'}
# {'Player': 'Ado', 'Romanized Name': 'Chon Gi-hyeon', 'Nationality': 'South Korea', 'Born': 'November 16, 1999 (age\xa025)', 'Status': 'Active', 'Role': 'DPS Coach', 'Team': 'ONSIDE GAMING', 'Signature Heroes': 'Genji, Tracer, Pharah', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$16,458'}
# {'Player': 'Ewan', 'Romanized Name': '', 'Nationality': 'United States', 'Born': '', 'Status': 'Active', 'Role': 'Support', 'Team': '', 'Signature Heroes': '', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,022'}
# {'Player': 'Xzahyo', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Kellex', 'Romanized Name': '', 'Nationality': 'Denmark', 'Born': 'February  9, 1999 (age\xa026)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Al Qadsiah', 'Signature Heroes': 'Lúcio, Mercy, Baptiste', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$115,750'}
# {'Player': 'Architect', 'Romanized Name': 'Park Min-ho', 'Nationality': 'South Korea', 'Born': 'February 26, 2000 (age\xa025)', 'Status': 'Active', 'Role': 'DPS Flex', 'Team': '', 'Signature Heroes': 'Genji, Pharah, Tracer', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$162,341'}
# {'Player': 'Insane', 'Romanized Name': 'Song Chunhui', 'Nationality': 'China', 'Born': 'February 21, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Milk Tea', 'Signature Heroes': 'Cassidy, Tracer, Ashe', 'Game Appearances': '', 'Approx. Total Winnings': '$11,270'}
# {'Player': 'SKAI', 'Romanized Name': '', 'Nationality': 'Romania', 'Born': 'May 19, 2001 (age\xa024)', 'Status': 'Active', 'Role': 'Support', 'Team': 'The Ultimates', 'Signature Heroes': 'Baptiste, Kiriko, Ana', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$50,536'}
# {'Player': 'Jasm1ne', 'Romanized Name': 'Jeong Jong-min', 'Nationality': 'South Korea', 'Born': 'September 19, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'All Gamers Global', 'Signature Heroes': 'D.Va, Zarya, Sigma', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$7,063'}
# {'Player': 'Bilideng', 'Romanized Name': 'Chen Cheng', 'Nationality': 'China', 'Born': '', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Team CC', 'Signature Heroes': 'D.Va, Sigma, Hazard', 'Game Appearances': '', 'Approx. Total Winnings': '$4,064'}
# {'Player': 'slowdive', 'Romanized Name': 'Majed Alghamdi', 'Nationality': 'Saudi Arabia', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Team Vision', 'Signature Heroes': 'Ashe, Widowmaker, Tracer', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$7,823'}
# {'Player': 'nuka', 'Romanized Name': 'Nukada Ryunosuke', 'Nationality': 'Japan', 'Born': 'April 20, 1996 (age\xa029)', 'Status': 'Retired', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Lúcio, Brigitte, Kiriko', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$283'}
# {'Player': 'Genius91', 'Romanized Name': 'Chen Shuhan', 'Nationality': 'China', 'Born': '', 'Status': 'Active', 'Role': 'Manager Tank', 'Team': 'Team XX', 'Signature Heroes': 'Sigma, D.Va, Mercy', 'Game Appearances': '', 'Approx. Total Winnings': '$610'}
# {'Player': 'Attack', 'Romanized Name': 'Kim Jun-hwa', 'Nationality': 'South Korea', 'Born': 'May  1, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'ONSIDE GAMING', 'Signature Heroes': 'D.Va, Sigma, Zarya', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$28,497'}
# {'Player': 'decade', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Twe12e', 'Romanized Name': 'Huang Canmei', 'Nationality': 'China', 'Born': 'April 22, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Ashe, Widowmaker, Cassidy', 'Game Appearances': '', 'Approx. Total Winnings': '$4,398'}
# {'Player': 'Viper', 'Romanized Name': 'Lee Jung-woong', 'Nationality': 'South Korea', 'Born': 'June 30, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'T1', 'Signature Heroes': 'Genji, Tracer, Mei', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$25,796'}
# {'Player': 'meruna', 'Romanized Name': '', 'Nationality': 'Japan', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Nyam Gaming', 'Signature Heroes': 'Sojourn, Tracer, Widowmaker', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$376'}
# {'Player': 'AOY', 'Romanized Name': 'Abdulrahman Yousef', 'Nationality': 'Saudi Arabia', 'Born': 'January 18, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'Support Tank', 'Team': '', 'Signature Heroes': 'Lúcio, Ana, Baptiste', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$12,761'}
# {'Player': 'knife', 'Romanized Name': 'Lee Seon-woo', 'Nationality': 'South Korea', 'Born': 'July 21, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Team Liquid', 'Signature Heroes': 'Tracer, Echo, Sojourn', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$19,705'}
# {'Player': 'GaaRa', 'Romanized Name': 'Mustafa Alabdulsalam', 'Nationality': 'Saudi Arabia', 'Born': 'April  8, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Gen.G Esports', 'Signature Heroes': 'Lúcio, Brigitte, Mercy', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$20,735'}
# {'Player': 'JBJ', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Ryujehong', 'Romanized Name': 'Ryu Je-hong', 'Nationality': 'South Korea', 'Born': 'September  5, 1991 (age\xa033)', 'Status': 'Active', 'Role': 'Support Streamer', 'Team': 'Old Ocean', 'Signature Heroes': 'Ana, Zenyatta, Lifeweaver', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$91,901'}
# {'Player': 'Sauna', 'Romanized Name': '', 'Nationality': 'Finland', 'Born': 'October  3, 2004 (age\xa020)', 'Status': 'Inactive', 'Role': 'DPS', 'Team': 'SrPeakCheck', 'Signature Heroes': 'Tracer, Pharah, Genji', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$46,960'}
# {'Player': 'Despair', 'Romanized Name': 'Choy Yu-ting', 'Nationality': 'Hong Kong', 'Born': 'June 12, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'MENG GONG 2', 'Signature Heroes': 'Pharah, Echo, Tracer', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,542'}
# {'Player': 'pOv', 'Romanized Name': 'Wang Mengyu', 'Nationality': 'China', 'Born': 'February 14, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Home E', 'Signature Heroes': 'Mercy, Brigitte, Lúcio', 'Game Appearances': '', 'Approx. Total Winnings': '$4,184'}
# {'Player': 'K4ne', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Ken', 'Romanized Name': '', 'Nationality': 'Belgium', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Team Peps', 'Signature Heroes': 'Ashe, Echo, Junkrat', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$12,442'}
# {'Player': 'Dumbbell', 'Romanized Name': 'Hwang Tae-san', 'Nationality': 'South Korea', 'Born': 'July  9, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'Tank Support', 'Team': 'Cold Metal', 'Signature Heroes': 'Sigma, D.Va, Ana', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,165'}
# {'Player': 'Love', 'Romanized Name': '', 'Nationality': 'Sweden', 'Born': 'July 25, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'ZoKorp Esports', 'Signature Heroes': 'Widowmaker, Tracer, Ashe', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$13,629'}
# {'Player': 'Fone', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'March  7, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'DPS Tank', 'Team': 'University of Texas at Dallas ExO: Sakura', 'Signature Heroes': 'Reaper, Mei, Sombra', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$2,364'}
# {'Player': 'Proud', 'Romanized Name': 'Hong Suk-jin', 'Nationality': 'South Korea', 'Born': 'November 12, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'T1', 'Signature Heroes': 'Ashe, Cassidy, Widowmaker', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$14,744'}
# {'Player': 'FARMER', 'Romanized Name': 'Kim Yea-han', 'Nationality': 'South Korea', 'Born': 'December  9, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'Tank', 'Team': '', 'Signature Heroes': '', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,627'}
# {'Player': 'fya', 'Romanized Name': 'Fan Zi', 'Nationality': 'China', 'Born': 'June 14, 1997 (age\xa028)', 'Status': 'Active', 'Role': 'Coach Support', 'Team': 'ZONES', 'Signature Heroes': 'Mercy, Lúcio, Zenyatta', 'Game Appearances': '', 'Approx. Total Winnings': '$20,186'}
# {'Player': 'AMANE', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Aniyun', 'Romanized Name': 'Yunhee Chi', 'Nationality': 'United States South Korea China', 'Born': 'June  8, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Al Qadsiah Corals', 'Signature Heroes': 'Baptiste, Ana, Kiriko', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$8,879'}
# {'Player': 'Langley', 'Romanized Name': '', 'Nationality': 'Japan', 'Born': '', 'Status': 'Active', 'Role': 'Support DPS', 'Team': '', 'Signature Heroes': 'Baptiste, Kiriko', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$671'}
# {'Player': 'Leonopteryx', 'Romanized Name': 'Keisuke Yamamoto', 'Nationality': 'Japan', 'Born': 'February 10, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'Tank', 'Team': '', 'Signature Heroes': 'Winston, Orisa, Junker Queen', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$2,538'}
# {'Player': 'MER1T', 'Romanized Name': 'Choi Tae-min', 'Nationality': 'South Korea', 'Born': 'June 21, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Team Falcons', 'Signature Heroes': 'Sojourn, Widowmaker, Ashe', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$417,085'}
# {'Player': 'Astro', 'Romanized Name': '', 'Nationality': 'United States', 'Born': '', 'Status': 'Retired', 'Role': 'Manager', 'Team': '', 'Signature Heroes': '', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': ''}
# {'Player': 'KIVIS', 'Romanized Name': 'Jeong Yeon-woo', 'Nationality': 'South Korea', 'Born': 'April 27, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Ana, Kiriko, Zenyatta', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,435'}
# {'Player': 'lumi', 'Romanized Name': '', 'Nationality': 'Singapore', 'Born': 'February  7, 2002 (age\xa023)', 'Status': 'Retired', 'Role': 'Tank Support', 'Team': '', 'Signature Heroes': 'D.Va, Junker Queen, Lúcio', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$6,051'}
# {'Player': 'Proxy', 'Romanized Name': 'Moon Seo-jin', 'Nationality': 'South Korea', 'Born': 'November 14, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'Tank SUP', 'Team': '', 'Signature Heroes': 'Ana, Zenyatta, Zarya', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,068'}
# {'Player': 'dra', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'seeker', 'Romanized Name': '', 'Nationality': 'Canada United States', 'Born': 'August  7, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Spacestation Gaming', 'Signature Heroes': 'Sojourn, Widowmaker, Bastion', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$35,853'}
# {'Player': 'Lukemino', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'February 12, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Sign Esports NTMR', 'Signature Heroes': 'Baptiste, Lúcio, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$47,453'}
# {'Player': 'winter', 'Romanized Name': 'Wang Feiyu', 'Nationality': 'China', 'Born': '', 'Status': 'Retired', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Tracer, Genji, Pharah', 'Game Appearances': '', 'Approx. Total Winnings': '$40,272'}
# {'Player': 'elva', 'Romanized Name': 'Song Hyuk-jun', 'Nationality': 'South Korea', 'Born': 'March 26, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Genji, Tracer, Echo', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$14,886'}
# {'Player': 's9mm', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'September 11, 2002 (age\xa022)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Supernova Winthrop University', 'Signature Heroes': 'Echo, Genji, Hanzo', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$76,933'}
# {'Player': 'WGYM', 'Romanized Name': 'Fynn Corrigan', 'Nationality': 'Japan Canada', 'Born': 'January 12, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Please Not Hero Ban', 'Signature Heroes': 'Lúcio, Brigitte', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,400'}
# {'Player': 'JayCo', 'Romanized Name': 'Tanavit Kotcharin', 'Nationality': 'Thailand', 'Born': 'November 16, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'I LOVE YOU', 'Signature Heroes': 'Genji, Pharah, Tracer', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$4,382'}
# {'Player': 'PaLee', 'Romanized Name': 'Panachai Prathomchandee', 'Nationality': 'Thailand', 'Born': 'November  4, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Ana, Kiriko, Lúcio', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$15,832'}
# {'Player': 'ZEST', 'Romanized Name': 'Kim Hyun-woo', 'Nationality': 'South Korea', 'Born': 'June  5, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'T1', 'Signature Heroes': 'Genji, Tracer, Pharah', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$52,959'}
# {'Player': 'Maybe', 'Romanized Name': '', 'Nationality': 'United Kingdom', 'Born': 'June 25, 1990 (age\xa035)', 'Status': 'Inactive', 'Role': 'Coach', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'ARLLY', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Cjay', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'September  2, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Support Coach', 'Team': 'Spacestation Gaming Northwood University Blue DhillKucks', 'Signature Heroes': 'Baptiste, Zenyatta, Ana', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$46,387'}
# {'Player': 'Junbin', 'Romanized Name': 'Park Jun-bin', 'Nationality': 'South Korea', 'Born': 'October  5, 2005 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Crazy Raccoon', 'Signature Heroes': 'Wrecking Ball, Winston, Orisa', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$167,293'}
# {'Player': 'D0D0', 'Romanized Name': 'Hyeon Jae-woong', 'Nationality': 'South Korea', 'Born': 'August 20, 2005 (age\xa019)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Nyam Gaming', 'Signature Heroes': 'Genji, Echo, Tracer', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$604'}
# {'Player': 'KL1', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': '1zU', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Casanova', 'Romanized Name': 'Zhang Yurui', 'Nationality': 'China', 'Born': 'March 18, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Sojourn, Ashe, Widowmaker', 'Game Appearances': '', 'Approx. Total Winnings': '$1,415'}
# {'Player': 'Kyrei', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Leedy', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Mimoza', 'Romanized Name': 'Tomohiro Tahara', 'Nationality': 'Japan', 'Born': 'July 23, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'Support', 'Team': 'VARREL', 'Signature Heroes': 'Kiriko, Illari, Lúcio', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$3,276'}
# {'Player': 'ChoiSehwan', 'Romanized Name': 'Choi Se-hwan', 'Nationality': 'South Korea', 'Born': 'October 13, 2002 (age\xa022)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Team Vision', 'Signature Heroes': 'Genji, Echo, Tracer', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$18,949'}
# {'Player': 'ZzetaA', 'Romanized Name': 'Tanavit Kotcharin', 'Nationality': 'Thailand', 'Born': 'November 16, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'I LOVE YOU', 'Signature Heroes': 'Genji, Pharah, Tracer', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$4,382'}
# {'Player': 'Renko', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'August 12, 2002 (age\xa022)', 'Status': 'Retired', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Zenyatta, Ana, Baptiste', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$30,789'}
# {'Player': 'EuclidEUC', 'Romanized Name': '', 'Nationality': 'Japan', 'Born': 'September 11, 1997 (age\xa027)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Nyam Gaming', 'Signature Heroes': 'Brigitte, Kiriko, Ana', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$751'}
# {'Player': 'Diya', 'Romanized Name': 'Lu Weida', 'Nationality': 'China', 'Born': 'July 30, 1999 (age\xa025)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'ROC Esports', 'Signature Heroes': 'Widowmaker, Tracer, Cassidy', 'Game Appearances': 'Overwatch', 'Approx. Total Winnings': '$86,639'}
# {'Player': 'FDGod', 'Romanized Name': '', 'Nationality': 'France Indonesia', 'Born': 'August 27, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Team Peps', 'Signature Heroes': 'Lúcio, Brigitte, Mercy', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$66,322'}
# {'Player': 'zeruhh', 'Romanized Name': '', 'Nationality': 'United States Ecuador', 'Born': 'September 27, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'DPS Coach', 'Team': 'Team Liquid Winthrop University', 'Signature Heroes': 'Genji, Tracer, Reaper', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$36,021'}
# {'Player': 'Daisy', 'Romanized Name': 'Shiono Hiromu', 'Nationality': 'Japan', 'Born': 'June 15, 1999 (age\xa026)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Aplomb Tiger', 'Signature Heroes': 'Tracer, Ashe, Widowmaker', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$4,501'}
# {'Player': 'cjay', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'September  2, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Support Coach', 'Team': 'Spacestation Gaming Northwood University Blue DhillKucks', 'Signature Heroes': 'Baptiste, Zenyatta, Ana', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$46,387'}
# {'Player': 'Chu', 'Romanized Name': '', 'Nationality': 'United Kingdom', 'Born': '', 'Status': 'Retired', 'Role': 'Coach', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'GFONAFASK', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'UltraViolet', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'April  1, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support DPS', 'Team': 'Geekay Esports Winthrop University', 'Signature Heroes': 'Baptiste, Zenyatta, Ana', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$103,468'}
# {'Player': 'Akie', 'Romanized Name': 'Park Do-yun', 'Nationality': 'South Korea', 'Born': 'August 21, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Little Sheep', 'Signature Heroes': 'Hazard, Orisa, Zarya', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$976'}
# {'Player': 'NuoRan', 'Romanized Name': 'Liu Xin', 'Nationality': 'China', 'Born': '', 'Status': 'Active', 'Role': 'Supports', 'Team': 'Blade', 'Signature Heroes': 'Lúcio, Brigitte', 'Game Appearances': '', 'Approx. Total Winnings': '$5,250'}
# {'Player': 'ChiYo', 'Romanized Name': 'Han Hyeon-seok', 'Nationality': 'South Korea', 'Born': 'September  8, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Team Falcons', 'Signature Heroes': 'Lúcio, Mercy, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$383,974'}
# {'Player': 'Kio', 'Romanized Name': '', 'Nationality': 'France', 'Born': 'March 11, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Cassidy, Widowmaker, Sojourn', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$5,283'}
# {'Player': 'HYE', 'Romanized Name': 'Chatin Pakdeepong', 'Nationality': 'Thailand', 'Born': 'January  9, 1999 (age\xa026)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Genji, Reaper, Tracer', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$911'}
# {'Player': 'Haku', 'Romanized Name': '', 'Nationality': 'Japan United States', 'Born': '', 'Status': 'Inactive', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Zenyatta, Ana, Moira', 'Game Appearances': 'Overwatch', 'Approx. Total Winnings': '$13,017'}
# {'Player': 'Rakattack', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'September 22, 2002 (age\xa022)', 'Status': 'Active', 'Role': 'Support Streamer', 'Team': 'The Gatos Guapos Winthrop University Gen.G Esports', 'Signature Heroes': 'Lifeweaver, Brigitte, Lúcio', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$42,815'}
# {'Player': 'Flora', 'Romanized Name': 'Yim Young-woo', 'Nationality': 'South Korea', 'Born': 'December 26, 2002 (age\xa022)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'ZETA DIVISION', 'Signature Heroes': 'Cassidy, Ashe, Widowmaker', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$37,264'}
# {'Player': 'Chase', 'Romanized Name': 'Oleksandr Okseschenko', 'Nationality': 'Ukraine', 'Born': 'April 23, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Tank', 'Team': '', 'Signature Heroes': 'Wrecking Ball, Winston, Doomfist', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$20,400'}
# {'Player': 'Qlm', 'Romanized Name': 'Nawaf', 'Nationality': 'Saudi Arabia', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Al Qadsiah Penn State University', 'Signature Heroes': 'Sojourn, Widowmaker, Ashe', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$12,149'}
# {'Player': 'eisgnom', 'Romanized Name': '', 'Nationality': 'Germany', 'Born': 'February 25, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Virtus.pro', 'Signature Heroes': 'D.Va, Doomfist, Winston', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$9,640'}
# {'Player': 'Tred', 'Romanized Name': '', 'Nationality': 'United Kingdom', 'Born': 'June 10, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Team Peps St. Clair College', 'Signature Heroes': 'D.Va, Doomfist, Winston', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$16,149'}
# {'Player': 'Qloud', 'Romanized Name': 'Takashi Umeda', 'Nationality': 'Japan', 'Born': 'July 15, 2000 (age\xa025)', 'Status': 'Active', 'Role': 'Support', 'Team': 'VARREL', 'Signature Heroes': 'Baptiste, Ana, Kiriko', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$9,606'}
# {'Player': 'GAP', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'April  5, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'Tank', 'Team': '', 'Signature Heroes': 'Mauga, Ramattra, Orisa', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,055'}
# {'Player': 'AZent', 'Romanized Name': 'Jang Hyeon-ik', 'Nationality': 'South Korea', 'Born': 'December 30, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'REVATI', 'Signature Heroes': 'Genji, Pharah, Tracer', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$596'}
# {'Player': 'Drunk', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Vision', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'August 12, 2002 (age\xa022)', 'Status': 'Active', 'Role': 'Coach DPS', 'Team': 'Dreamland', 'Signature Heroes': 'Hanzo, Widowmaker, Cassidy', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$34,468'}
# {'Player': 'BILIDENG', 'Romanized Name': 'Chen Cheng', 'Nationality': 'China', 'Born': '', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Team CC', 'Signature Heroes': 'D.Va, Sigma, Hazard', 'Game Appearances': '', 'Approx. Total Winnings': '$4,064'}
# {'Player': 'Nico', 'Romanized Name': 'Fujikawa Daisuke', 'Nationality': 'Japan', 'Born': 'February  3, 1999 (age\xa026)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'VARREL', 'Signature Heroes': 'Tracer, Sojourn, Genji', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$13,368'}
# {'Player': 'Becky', 'Romanized Name': 'Kim Il-ha', 'Nationality': 'South Korea', 'Born': 'October  2, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Echo, Tracer, Mei', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$6,377'}
# {'Player': 'Damo', 'Romanized Name': 'Zhong Haoyang', 'Nationality': 'Hong Kong', 'Born': 'August 18, 2002 (age\xa022)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Cold Metal', 'Signature Heroes': 'Winston, Orisa, D.Va', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$240'}
# {'Player': 'Lumi', 'Romanized Name': '', 'Nationality': 'Singapore', 'Born': 'February  7, 2002 (age\xa023)', 'Status': 'Retired', 'Role': 'Tank Support', 'Team': '', 'Signature Heroes': 'D.Va, Junker Queen, Lúcio', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$6,051'}
# {'Player': 'SoloZen', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'April 29, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Zenyatta, Baptiste, Kiriko', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,377'}
# {'Player': 'Sungeun', 'Romanized Name': 'Park Sung-eun', 'Nationality': 'South Korea', 'Born': 'October 24, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Amplify', 'Signature Heroes': 'Winston, Reinhardt, Orisa', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,505'}
# {'Player': 'guxue', 'Romanized Name': 'Xu Qiulin', 'Nationality': 'China', 'Born': 'October 16, 2000 (age\xa024)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Weibo Gaming', 'Signature Heroes': 'Winston, Reinhardt, Doomfist', 'Game Appearances': 'Overwatch', 'Approx. Total Winnings': '$190,964'}
# {'Player': 'Hop3r', 'Romanized Name': 'Park Se-hyun', 'Nationality': 'South Korea', 'Born': 'January 22, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': '', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$534'}
# {'Player': 'feiyang', 'Romanized Name': 'Chen Shihang', 'Nationality': 'China', 'Born': 'November  2, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Team XX', 'Signature Heroes': 'Roadhog, Zarya, D.Va', 'Game Appearances': '', 'Approx. Total Winnings': '$2,697'}
# {'Player': 'HEISER', 'Romanized Name': 'Cho-Yu-hyun', 'Nationality': 'South Korea', 'Born': 'February  7, 2008 (age\xa017)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Poker Face', 'Signature Heroes': 'Winston, Reinhardt, Ramattra', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$2,315'}
# {'Player': 'JinMu', 'Romanized Name': 'Yi Hu', 'Nationality': 'China', 'Born': 'May 15, 1999 (age\xa026)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'ROC Esports', 'Signature Heroes': 'Genji, Pharah, Echo', 'Game Appearances': 'Overwatch', 'Approx. Total Winnings': '$39,291'}
# {'Player': 'Sour4', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'iMOH97', 'Romanized Name': 'Mohammed Alinize', 'Nationality': 'Saudi Arabia', 'Born': 'August 24, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Tank Caster', 'Team': '', 'Signature Heroes': 'D.Va, Sigma, Zarya', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$37,280'}
# {'Player': 'SeungAn', 'Romanized Name': 'Lee Seung-an', 'Nationality': 'South Korea', 'Born': 'October 30, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'VEC', 'Signature Heroes': 'Sigma, D.Va, Ramattra', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$4,006'}
# {'Player': 'Edison', 'Romanized Name': 'Kim Tae-hoon', 'Nationality': 'South Korea', 'Born': 'November 16, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'REJECT', 'Signature Heroes': 'Tracer, Reaper, Sojourn', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$355,647'}
# {'Player': 'Gaisen', 'Romanized Name': 'Mori Yoshiki', 'Nationality': 'Japan', 'Born': 'October 19, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Aplomb Tiger', 'Signature Heroes': 'Kiriko, Baptiste, Illari', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,183'}
# {'Player': 'Majin', 'Romanized Name': '', 'Nationality': 'France', 'Born': 'January  2, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': '', 'Signature Heroes': 'D.Va, Sigma, Ramattra', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,763'}
# {'Player': 'Aester', 'Romanized Name': 'Shin Seung-woo', 'Nationality': 'South Korea', 'Born': 'October 22, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Support DPS', 'Team': 'Team XX', 'Signature Heroes': 'Tracer, Mei, Echo', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$6,304'}
# {'Player': 'Proxiezs', 'Romanized Name': '', 'Nationality': 'Indonesia', 'Born': '', 'Status': 'Active', 'Role': 'DPS Support', 'Team': 'Cold Metal', 'Signature Heroes': 'Sojourn, Genji, Baptiste', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$2,262'}
# {'Player': 'Univ2r', 'Romanized Name': 'Jang Geon-ik', 'Nationality': 'South Korea', 'Born': 'December 30, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Full House', 'Signature Heroes': 'Juno, Ana, Kiriko', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$250'}
# {'Player': 'WhoRU', 'Romanized Name': 'Lee Seung-jun', 'Nationality': 'South Korea', 'Born': 'August 23, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Gen.G Esports', 'Signature Heroes': 'Genji, Tracer, Pharah', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$288,887'}
# {'Player': 'Landon', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'November  7, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Al Qadsiah', 'Signature Heroes': 'Baptiste, Kiriko, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$114,937'}
# {'Player': 'Misin', 'Romanized Name': 'Choi Hyun-geun', 'Nationality': 'South Korea', 'Born': 'April 22, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Ana, Zenyatta', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$5,700'}
# {'Player': 'Mew', 'Romanized Name': 'Li Xianyao', 'Nationality': 'China', 'Born': 'September 29, 2000 (age\xa024)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Weibo Gaming', 'Signature Heroes': 'Mercy, Brigitte, Lúcio', 'Game Appearances': 'Overwatch', 'Approx. Total Winnings': '$60,357'}
# {'Player': 'Rrmy', 'Romanized Name': '', 'Nationality': 'Japan', 'Born': 'July 25, 1996 (age\xa029)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'REJECT', 'Signature Heroes': 'Tracer, Genji, Ashe', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$2,800'}
# {'Player': 'par', 'Romanized Name': '', 'Nationality': 'New Zealand', 'Born': 'April  9, 2003 (age\xa022)', 'Status': 'Retired', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Sojourn, Tracer, Reaper', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$7,228'}
# {'Player': 'xzodyal', 'Romanized Name': '', 'Nationality': 'Spain', 'Born': 'December 29, 2006 (age\xa018)', 'Status': 'Active', 'Role': 'DPS Coach', 'Team': 'Gen.G Esports', 'Signature Heroes': 'Sojourn, Cassidy, Widowmaker', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$10,747'}
# {'Player': 'Kellan', 'Romanized Name': 'Kim Min-jae', 'Nationality': 'South Korea', 'Born': 'October  9, 2003 (age\xa021)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Spacestation Gaming', 'Signature Heroes': 'Winston, Reinhardt, Wrecking Ball', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$37,671'}
# {'Player': 'HINIS4Ku', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# ...
# {'Player': 'ky0n', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Lightt', 'Romanized Name': '', 'Nationality': 'Taiwan United States', 'Born': 'December 19, 2002 (age\xa022)', 'Status': 'Active', 'Role': 'Flex', 'Team': 'The Gatos Guapos', 'Signature Heroes': 'Doomfist, Widowmaker, Kiriko', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$9,576'}
# {'Player': 'ZeSin', 'Romanized Name': 'Song Yun-jin', 'Nationality': 'South Korea', 'Born': 'March 24, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'VEC', 'Signature Heroes': 'Widowmaker, Sojourn, Cassidy', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$2,106'}
# {'Player': 'k1ng', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'July 13, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Anomaly', 'Signature Heroes': 'Genji, Tracer, Echo', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$32,679'}
# {'Player': 'LIP', 'Romanized Name': 'Lee Jae-won', 'Nationality': 'South Korea', 'Born': 'November  5, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Crazy Raccoon', 'Signature Heroes': 'Sombra, Sojourn, Widowmaker', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$601,045'}
# {'Player': 'False', 'Romanized Name': '', 'Nationality': 'Canada', 'Born': 'February 16, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Supernova', 'Signature Heroes': 'D.Va, Sigma, Zarya', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$32,249'}
# {'Player': 'Hyeonjun', 'Romanized Name': 'Hong Hyeon-jun', 'Nationality': 'South Korea', 'Born': 'April 19, 2007 (age\xa018)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Little Sheep', 'Signature Heroes': 'Illari, Ana, Kiriko', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$976'}
# {'Player': 'search', 'Romanized Name': 'Bong Wook', 'Nationality': 'South Korea', 'Born': 'May  4, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support Coach', 'Team': 'VEC', 'Signature Heroes': 'Lúcio, Brigitte, Mercy', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$3,110'}
# {'Player': 'Skyshow', 'Romanized Name': 'Wan Wenjun', 'Nationality': 'China', 'Born': 'November 24, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Little Sheep', 'Signature Heroes': 'Hanzo, Widowmaker, Cassidy', 'Game Appearances': '', 'Approx. Total Winnings': '$7,367'}
# {'Player': 'Kusari', 'Romanized Name': 'Tang Leyuan', 'Nationality': 'China', 'Born': 'July  2, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Little Sheep', 'Signature Heroes': 'Kiriko, Juno, Ana', 'Game Appearances': '', 'Approx. Total Winnings': '$3,033'}
# {'Player': 'Viol2t', 'Romanized Name': 'Park Min-ki', 'Nationality': 'South Korea', 'Born': 'April 17, 2000 (age\xa025)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Team Vision', 'Signature Heroes': 'Zenyatta, Baptiste, Lúcio', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$644,276'}
# {'Player': 'Regr3T', 'Romanized Name': '', 'Nationality': 'Australia', 'Born': 'February 18, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'The Bakery I LOVE YOU', 'Signature Heroes': 'Widowmaker, Cassidy, Sojourn', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$916'}
# {'Player': 'Fearful', 'Romanized Name': 'Lee Min-ho', 'Nationality': 'South Korea', 'Born': 'April  5, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'Tank', 'Team': '', 'Signature Heroes': 'Winston, Wrecking Ball, Reinhardt', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,875'}
# {'Player': 'Flicker', 'Romanized Name': 'Xu Cheng', 'Nationality': 'China', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Team Equal', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': '$3,354'}
# {'Player': 'TVNT', 'Romanized Name': 'Abdualziz Altmimi', 'Nationality': 'Saudi Arabia', 'Born': 'October 19, 2005 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Twisted Minds', 'Signature Heroes': 'Sigma, D.Va, Ramattra', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$49,889'}
# {'Player': 'Neuu', 'Romanized Name': '', 'Nationality': 'Australia', 'Born': 'February 19, 2001 (age\xa024)', 'Status': 'Retired', 'Role': 'DPS Tank', 'Team': '', 'Signature Heroes': 'Ashe, Sojourn, Cassidy', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$7,184'}
# {'Player': 'LeeSooMin', 'Romanized Name': 'Lee Soo-Min', 'Nationality': 'South Korea', 'Born': 'July 10, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'Support', 'Team': 'All Gamers Global', 'Signature Heroes': 'Ana, Zenyatta, Brigitte', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$16,482'}
# {'Player': 'Wen', 'Romanized Name': 'Wen Shihai', 'Nationality': 'China', 'Born': '', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Homie E', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': '$3,136'}
# {'Player': 'Pugz', 'Romanized Name': '', 'Nationality': 'Australia', 'Born': '', 'Status': 'Active', 'Role': 'Support', 'Team': 'The Bakery', 'Signature Heroes': 'Brigitte, Lúcio, Kiriko', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$846'}
# {'Player': 'Erikek', 'Romanized Name': '', 'Nationality': 'Spain Denmark', 'Born': 'July 16, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'Tank', 'Team': '', 'Signature Heroes': 'Winston, Ramattra, Sigma', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$3,753'}
# {'Player': 'FodCarry', 'Romanized Name': 'So Hyun-seo', 'Nationality': 'South Korea', 'Born': 'July 16, 2007 (age\xa018)', 'Status': 'Active', 'Role': 'DPS Coach', 'Team': '', 'Signature Heroes': 'Tracer, Genji, Sojourn', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$1,675'}
# {'Player': 'Jimmy', 'Romanized Name': 'Lei Yujia', 'Nationality': 'China', 'Born': 'July  1, 2001 (age\xa024)', 'Status': 'Active', 'Role': 'Streamer DPS', 'Team': 'Super Levi', 'Signature Heroes': 'Hanzo, Widowmaker, Ashe', 'Game Appearances': '', 'Approx. Total Winnings': '$33,303'}
# {'Player': 'CARU', 'Romanized Name': 'Kim Beom-jun', 'Nationality': 'South Korea', 'Born': 'September 10, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'Support', 'Team': '', 'Signature Heroes': 'Ana, Moira, Kiriko', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$4,660'}
# {'Player': 'ShakeIt', 'Romanized Name': 'Narabodin Nakhonkhwang', 'Nationality': 'Thailand', 'Born': 'February 14, 2001 (age\xa024)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Sojourn, Widowmaker, Soldier: 76', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,051'}
# {'Player': 'RULER', 'Romanized Name': 'Kim Yi-gun', 'Nationality': 'South Korea', 'Born': 'July 10, 2006 (age\xa019)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'ZONES', 'Signature Heroes': 'Zarya, D.Va, Sigma', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$3,413'}
# {'Player': 'Colourhex', 'Romanized Name': '', 'Nationality': 'New Zealand', 'Born': 'November 17, 1997 (age\xa027)', 'Status': 'Active', 'Role': 'DPS Flex', 'Team': 'The Gatos Guapos', 'Signature Heroes': 'Echo, Hanzo, Kiriko', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$18,881'}
# {'Player': 'Sonic100', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Water', 'Romanized Name': 'Lee Min-Seong', 'Nationality': 'South Korea', 'Born': 'July  8, 1998 (age\xa027)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'ZG', 'Signature Heroes': 'Genji, Pharah, Hanzo', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$13,185'}
# {'Player': 'GAGA', 'Romanized Name': 'Qiu Jiaxin', 'Nationality': 'China', 'Born': 'April 12, 2000 (age\xa025)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'Team CC', 'Signature Heroes': 'Wrecking Ball, Reinhardt, Winston', 'Game Appearances': '', 'Approx. Total Winnings': '$77,466'}
# {'Player': 'Keios', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Chicken', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'pythorn', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Probe', 'Romanized Name': 'Jung Jun-young', 'Nationality': 'South Korea', 'Born': 'March  6, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Widowmaker, Cassidy, Freja', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$34,419'}
# {'Player': 'POSS', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'Belosrea', 'Romanized Name': 'Hwang Gyu-tae', 'Nationality': 'South Korea', 'Born': 'January 10, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'ROC Esports', 'Signature Heroes': 'Winston, Reinhardt, Wrecking Ball', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$43,153'}
# {'Player': 'Kaneki', 'Romanized Name': 'Liu Nian', 'Nationality': 'China', 'Born': 'August 16, 2002 (age\xa022)', 'Status': 'Active', 'Role': 'DPS Support', 'Team': 'Team CC', 'Signature Heroes': 'Kiriko, Ana, Pharah', 'Game Appearances': '', 'Approx. Total Winnings': '$37,173'}
# {'Player': 'AOKIGAHARA', 'Romanized Name': 'Tamotsu Nobuhara', 'Nationality': 'Japan', 'Born': '', 'Status': 'Active', 'Role': 'DPS Support', 'Team': 'VortexWolf', 'Signature Heroes': 'Sojourn, Widowmaker, Ashe', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$1,100'}
# {'Player': 'wya', 'Romanized Name': 'Qi Haomiao', 'Nationality': 'China', 'Born': 'December 21, 2000 (age\xa024)', 'Status': 'Active', 'Role': 'Support', 'Team': 'ZONES', 'Signature Heroes': 'Ana, Zenyatta, D.Va', 'Game Appearances': '', 'Approx. Total Winnings': '$51,897'}
# {'Player': 'Nyang', 'Romanized Name': 'Park Su-young', 'Nationality': 'South Korea', 'Born': 'February  1, 2002 (age\xa023)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'The Gatos Guapos', 'Signature Heroes': 'Widowmaker, Ashe, Sojourn', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$19,105'}
# {'Player': 'Ackyyy', 'Romanized Name': '', 'Nationality': 'Australia', 'Born': 'November  5, 2001 (age\xa023)', 'Status': 'Active', 'Role': 'Support', 'Team': 'The Gatos Guapos', 'Signature Heroes': 'Ana, Kiriko, Baptiste', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$29,033'}
# {'Player': 'Huntin', 'Romanized Name': '', 'Nationality': 'Australia', 'Born': 'February 21, 2005 (age\xa020)', 'Status': 'Active', 'Role': 'Support', 'Team': 'The Bakery', 'Signature Heroes': 'Juno, Ana, Kiriko', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$681'}
# {'Player': 'Mikouw', 'Romanized Name': 'Wan Tsz-kit', 'Nationality': 'Hong Kong', 'Born': '', 'Status': 'Active', 'Role': 'DPS', 'Team': 'MENG GONG 2', 'Signature Heroes': 'Tracer, Hanzo, Widowmaker', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$6,672'}
# {'Player': 'Gur3um', 'Romanized Name': 'Jeon Yong-min', 'Nationality': 'South Korea', 'Born': 'June  1, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Tank', 'Team': '', 'Signature Heroes': 'Sigma, D.Va, Junker Queen', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$3,369'}
# {'Player': 'Pobi', 'Romanized Name': 'Jang Il-ji', 'Nationality': 'South Korea', 'Born': 'November 20, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'Tank', 'Team': 'I LOVE YOU', 'Signature Heroes': 'Winston, Wrecking Ball, Orisa', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$237'}
# {'Player': 'HyVision', 'Romanized Name': 'Nathawit Prajong', 'Nationality': 'Thailand', 'Born': 'November 26, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Sojourn, Ashe, Cassidy', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$9,487'}
# {'Player': 'Kai', 'Romanized Name': '', 'Nationality': 'United Kingdom', 'Born': 'June 17, 2000 (age\xa025)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'The Ultimates', 'Signature Heroes': 'Sojourn, Widowmaker, Ashe', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$203,285'}
# {'Player': 'Lilko', 'Romanized Name': 'Yi Jinlin', 'Nationality': 'China', 'Born': 'September  2, 2004 (age\xa020)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Homie E', 'Signature Heroes': 'Tracer, Echo, Genji', 'Game Appearances': '', 'Approx. Total Winnings': '$3,462'}
# {'Player': 'cow', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}
# {'Player': 'vigilante', 'Romanized Name': 'Kim Joon', 'Nationality': 'South Korea', 'Born': 'July  1, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'T1', 'Signature Heroes': 'Ana, Zenyatta, Baptiste', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$101,795'}
# {'Player': 'wub', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'April 12, 2001 (age\xa024)', 'Status': 'Retired', 'Role': 'DPS', 'Team': '', 'Signature Heroes': 'Widowmaker, Hanzo, Echo', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$31,981'}
# {'Player': 'SoOn', 'Romanized Name': '', 'Nationality': 'France', 'Born': 'February  4, 1994 (age\xa031)', 'Status': 'Active', 'Role': 'DPS', 'Team': 'Team Peps', 'Signature Heroes': 'Tracer, Widowmaker, Cassidy', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$115,549'}
# {'Player': 'SirMajed', 'Romanized Name': 'Majed Alrashied', 'Nationality': 'Saudi Arabia', 'Born': 'January 24, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Team Falcons', 'Signature Heroes': 'Illari, Baptiste, Zenyatta', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$110,189'}
# {'Player': 'EmolGa', 'Romanized Name': 'Ju Gi-woong', 'Nationality': 'South Korea', 'Born': 'January 20, 2003 (age\xa022)', 'Status': 'Active', 'Role': 'Support Tank', 'Team': 'Amplify', 'Signature Heroes': 'Sigma, D.Va, Lúcio', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$3,179'}
# {'Player': 'MSCG', 'Romanized Name': 'Prabda Watthanaworasakul', 'Nationality': 'Thailand', 'Born': 'February 10, 2004 (age\xa021)', 'Status': 'Active', 'Role': 'Support', 'Team': 'Cold Metal', 'Signature Heroes': 'Ana, Zenyatta, Kiriko', 'Game Appearances': 'Overwatch 2', 'Approx. Total Winnings': '$2,587'}
# {'Player': 'Infekted', 'Romanized Name': '', 'Nationality': 'United States', 'Born': 'February 13, 2007 (age\xa018)', 'Status': 'Active', 'Role': 'Tank Coach', 'Team': 'Team Liquid Winthrop University', 'Signature Heroes': 'Reinhardt, Wrecking Ball, Winston', 'Game Appearances': 'Overwatch Overwatch 2', 'Approx. Total Winnings': '$40,307'}
# {'Player': 'Tropica', 'Romanized Name': '', 'Nationality': '', 'Born': '', 'Status': '', 'Role': '', 'Team': '', 'Signature Heroes': '', 'Game Appearances': '', 'Approx. Total Winnings': ''}

# %%
import pandas as pd

# 수집한 데이터 리스트
all_data = []
for player in all_players:
    try:
        data = get_player_info(player)
        all_data.append(data)
    except Exception as e:
        print(f"Error fetching data for {player}: {e}")

# field_map 기준으로 열 순서 지정
columns = [
    "Player", "Romanized Name", "Nationality", "Born", "Status",
    "Role", "Team", "Signature Heroes", "Game Appearances", "Approx. Total Winnings"
]

# DataFrame 생성 및 CSV 저장
df = pd.DataFrame(all_data, columns=columns)
df.to_csv("esports_players_2025.csv", index=False, encoding="utf-8-sig")
